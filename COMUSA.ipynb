# %% [markdown]
# <a href="https://colab.research.google.com/github/ClaudioAQ/COMUSA/blob/master/COMUSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto Comusa
#
# Monitoramento da qualidade da água do Município de Novo Hamburgo (RS)
#
# (c) Claudio Fagundes Pereira

# %%
# Importação das bibliotecas
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# Importação dos dados file *.xlsx
df = pd.read_csv('C:/Users/profc/OneDrive/Documentos/COMUSA.csv', sep=';', encoding='utf8', decimal=',', usecols = [0,1,10,11,13,14,15,16])

# Excluir os campos de 'Total a Pagar (R$)' até 'Valor Água (R$)' para anonimizar

# %%
# Verificação dos dados importados
df.head()
# Out:
#    Vencimento Mês/Ano Referência  Cor (UC)  Turbidez (NTU)  \
# 0  20/02/2015             jan/15         3            0.44
# 1  20/03/2015             fev/15         2            0.69
# 2  20/04/2015             mar/15         2            0.48
# 3  20/05/2015             abr/15         1            0.48
# 4  20/06/2015             mai/15         1            0.50
#
#    Cloro Livre (mg/l)  Flúor (mg/l)    pH  % Coliformes Totais
# 0                0.71          0.73  6.68                 4.78
# 1                1.08          0.72  6.77                 0.97
# 2                1.10          0.74  6.66                 1.00
# 3                1.25          0.76  6.72                 1.00
# 4                1.23          0.78  6.72                 3.00

# %%
df.dtypes
# Out:
# Vencimento              object
# Mês/Ano Referência      object
# Cor (UC)                 int64
# Turbidez (NTU)         float64
# Cloro Livre (mg/l)     float64
# Flúor (mg/l)           float64
# pH                     float64
# % Coliformes Totais    float64
# dtype: object

# %%
# Cálculo da média de todos os indicadores
cor = df['Cor (UC)'].mean()
coliformes = df['% Coliformes Totais'].mean()
turbidez = df['Turbidez (NTU)'].mean()
cloro_livre = df['Cloro Livre (mg/l)'].mean()
fluor = df['Flúor (mg/l)'].mean()
pH = df['pH'].mean()

# %%
# Gráfico do pH
my_dpi = 200
plt.figure(figsize=(1100/my_dpi, 400/my_dpi), dpi = my_dpi)
 
# Plot do pH
plt.plot(df['Mês/Ano Referência'], df['pH'], marker='', color='black', linewidth=1.5)

# Add a title to say which style it is
plt.title('COMUSA: pH', fontsize=12, fontweight=0, color='black', loc='center')
plt.xlabel('Período', fontsize=6)
plt.ylabel('pH', fontsize=6, rotation=0)
plt.xticks(fontsize=4, rotation=70)
plt.yticks(fontsize=4)

# Add limits to Y axis
yinf = 5
ysup = 11
plt.ylim(yinf, ysup)

# Add lines for pH Parameters
plt.axhline(9.5, color ='b', linestyle = "dashdot")
plt.axhline(6, color ='b', linestyle = "dashdot")

plt.show()

# %%
# Gráfico do Cloro
my_dpi = 200
plt.figure(figsize=(1100/my_dpi, 400/my_dpi), dpi = my_dpi)
 
# Plot do pH
plt.plot(df['Mês/Ano Referência'], df['Cloro Livre (mg/l)'], marker='', color='black', linewidth=1.5)

# Add a title to say which style it is
plt.title('COMUSA: Cloro Livre (mg/l)', fontsize=12, fontweight=0, color='black', loc='center')
plt.xlabel('Período', fontsize=6)
plt.ylabel('Cloro Livre (mg/l)', fontsize=6, rotation=90)
plt.xticks(fontsize=4, rotation=70)
plt.yticks(fontsize=4)

# Add limits to Y axis
yinf = 0
ysup = 6
plt.ylim(yinf, ysup)

# Add lines for pH Parameters
plt.axhline(5, color ='b', linestyle = "dashdot")
plt.axhline(0.2, color ='b', linestyle = "dashdot")

plt.show()

# %%
# Gráfico do Flúor
my_dpi = 200
plt.figure(figsize=(1100/my_dpi, 400/my_dpi), dpi = my_dpi)
 
# Plot do pH
plt.plot(df['Mês/Ano Referência'], df['Flúor (mg/l)'], marker='', color='black', linewidth=1.5)

# Add a title to say which style it is
plt.title('COMUSA: Flúor (mg/l)', fontsize=12, fontweight=0, color='black', loc='center')
plt.xlabel('Período', fontsize=6)
plt.ylabel('Flúor (mg/l)', fontsize=6, rotation=90)
plt.xticks(fontsize=4, rotation=70)
plt.yticks(fontsize=4)

# Add limits to Y axis
yinf = 0
ysup = 1.5
plt.ylim(yinf, ysup)

# Add lines for pH Parameters
plt.axhline(0.9, color ='b', linestyle = "dashdot")
plt.axhline(0.6, color ='b', linestyle = "dashdot")

plt.show()

# %%
# Gráfico dos % Coliformes Totais
my_dpi = 200
plt.figure(figsize=(1100/my_dpi, 400/my_dpi), dpi = my_dpi)
 
# Plot do pH
plt.plot(df['Mês/Ano Referência'], df['% Coliformes Totais'], marker='', color='black', linewidth=1.5)

# Add a title to say which style it is
plt.title('COMUSA: Coliformes Totais (%)', fontsize=12, fontweight=0, color='black', loc='center')
plt.xlabel('Período', fontsize=6)
plt.ylabel('Coliformes Totais (%)', fontsize=6, rotation=90)
plt.xticks(fontsize=4, rotation=70)
plt.yticks(fontsize=4)

# Add limits to Y axis
yinf = 0
ysup = 10
plt.ylim(yinf, ysup)

# Add lines for pH Parameters
plt.axhline(5, color ='b', linestyle = "dashdot")
plt.axhline(0.1, color ='b', linestyle = "dashdot")

plt.show()

# %%
# Gráfico da Cor
my_dpi = 200
plt.figure(figsize=(1100/my_dpi, 400/my_dpi), dpi = my_dpi)
 
# Plot do pH
plt.plot(df['Mês/Ano Referência'], df['Cor (UC)'], marker='', color='black', linewidth=1.5)

# Add a title to say which style it is
plt.title('COMUSA: Cor (UC)', fontsize=12, fontweight=0, color='black', loc='center')
plt.xlabel('Período', fontsize=6)
plt.ylabel('Cor (UC)', fontsize=6, rotation=90)
plt.xticks(fontsize=4, rotation=70)
plt.yticks(fontsize=4)

# Add limits to Y axis
yinf = 0
ysup = 20
plt.ylim(yinf, ysup)

# Add lines for pH Parameters
plt.axhline(15, color ='b', linestyle = "dashdot")
plt.axhline(0.1, color ='b', linestyle = "dashdot")

plt.show()

# %%
# Gráfico da Turbidez
my_dpi = 200
plt.figure(figsize=(1100/my_dpi, 400/my_dpi), dpi = my_dpi)
 
# Plot do pH
plt.plot(df['Mês/Ano Referência'], df['Turbidez (NTU)'], marker='', color='black', linewidth=1.5)

# Add a title to say which style it is
plt.title('COMUSA: Turbidez (NTU)', fontsize=12, fontweight=0, color='black', loc='center')
plt.xlabel('Período', fontsize=6)
plt.ylabel('Turbidez (NTU)', fontsize=6, rotation=90)
plt.xticks(fontsize=4, rotation=70)
plt.yticks(fontsize=4)

# Add limits to Y axis
yinf = 0
ysup = 10
plt.ylim(yinf, ysup)

# Add lines for pH Parameters
plt.axhline(5, color ='b', linestyle = "dashdot")
plt.axhline(0.1, color ='b', linestyle = "dashdot")

plt.show()
